# %%
import numpy as np
import pandas as pd

# %%
V = pd.read_csv('gen_data/V.csv', header = None)

# %%
V.max().max()
# Out:
# 1.05

# %%
Y = pd.read_csv('gen_data/Y.csv', header = None)

# %%
Y
# Out:
#                                      0                                    1    \
# 0     9.34796077554253-30.7534616858728i  -2.78030115341206+9.16673548600215i
# 1    -2.78030115341206+9.16673548600215i   7.29257719853482-24.0307036346418i
# 2    -6.56765962213047+21.5867261998707i                                -0+0i
# 3                                  -0+0i                                -0+0i
# 4                                  -0+0i                                -0+0i
# ..                                   ...                                  ...
# 113                                -0+0i                                -0+0i
# 114                                -0+0i                                -0+0i
# 115                                -0+0i                                -0+0i
# 116                                -0+0i                                -0+0i
# 117                                -0+0i                                -0+0i
#
#                                      2                                   3    \
# 0    -6.56765962213047+21.5867261998707i                               -0+0i
# 1                                  -0+0i                               -0+0i
# 2     10.2679651856868-36.1328218177916i                               -0+0i
# 3                                  -0+0i    30.398343223854-132.80733432795i
# 4    -1.96818080476545+8.82006335745512i  -26.355985504208+119.500434274761i
# ..                                   ...                                 ...
# 113                                -0+0i                               -0+0i
# 114                                -0+0i                               -0+0i
# 115                                -0+0i                               -0+0i
# 116                                -0+0i                               -0+0i
# 117                                -0+0i                               -0+0i
#
#                                      4                                    5    \
# 0                                  -0+0i                                -0+0i
# 1                                  -0+0i                                -0+0i
# 2    -1.96818080476545+8.82006335745512i                                -0+0i
# 3     -26.355985504208+119.500434274761i                                -0+0i
# 4     36.2253142014528-196.903930532742i  -3.89192866323697+17.6608527575459i
# ..                                   ...                                  ...
# 113                                -0+0i                                -0+0i
# 114                                -0+0i                                -0+0i
# 115                                -0+0i                                -0+0i
# 116                                -0+0i                                -0+0i
# 117                                -0+0i                                -0+0i
#
#        6                    7      8      9    ...    108    109    110  \
# 0    -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# 1    -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# 2    -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# 3    -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# 4    -0+0i  0+37.4531835205992i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# ..     ...                  ...    ...    ...  ...    ...    ...    ...
# 113  -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# 114  -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# 115  -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# 116  -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
# 117  -0+0i                -0+0i  -0+0i  -0+0i  ...  -0+0i  -0+0i  -0+0i
#
#        111    112                                  113  \
# 0    -0+0i  -0+0i                                -0+0i
# 1    -0+0i  -0+0i                                -0+0i
# 2    -0+0i  -0+0i                                -0+0i
# 3    -0+0i  -0+0i                                -0+0i
# 4    -0+0i  -0+0i                                -0+0i
# ..     ...    ...                                  ...
# 113  -0+0i  -0+0i   23.7103829313552-107.252017136614i
# 114  -0+0i  -0+0i  -20.2732481269282+91.6703393565447i
# 115  -0+0i  -0+0i                                -0+0i
# 116  -0+0i  -0+0i                                -0+0i
# 117  -0+0i  -0+0i                                -0+0i
#
#                                      114                                 115  \
# 0                                  -0+0i                               -0+0i
# 1                                  -0+0i                               -0+0i
# 2                                  -0+0i                               -0+0i
# 3                                  -0+0i                               -0+0i
# 4                                  -0+0i                               -0+0i
# ..                                   ...                                 ...
# 113  -20.2732481269282+91.6703393565447i                               -0+0i
# 114    23.1205840448554-104.53543640035i                               -0+0i
# 115                                -0+0i  20.5834811509798-245.185584298436i
# 116                                -0+0i                               -0+0i
# 117                                -0+0i                               -0+0i
#
#                                     116                                 117
# 0                                 -0+0i                               -0+0i
# 1                                 -0+0i                               -0+0i
# 2                                 -0+0i                               -0+0i
# 3                                 -0+0i                               -0+0i
# 4                                 -0+0i                               -0+0i
# ..                                  ...                                 ...
# 113                               -0+0i                               -0+0i
# 114                               -0+0i                               -0+0i
# 115                               -0+0i                               -0+0i
# 116  1.59072371159841-6.76903707063152i                               -0+0i
# 117                               -0+0i  10.8252097470663-35.9089792060997i
#
# [118 rows x 118 columns]

# %%
Y2 = pd.read_csv('gen_data/Y2.csv', header = None)

# %%
Y2
# Out:
#                                      0                                    1    \
# 0     9.34796077554253-30.7534616858728i  -2.78030115341206+9.16673548600215i
# 1    -2.78030115341206+9.16673548600215i   7.29257719853482-24.0307036346418i
# 2    -6.56765962213047+21.5867261998707i                                 0+0i
# 3                                   0+0i                                 0+0i
# 4                                   0+0i                                 0+0i
# ..                                   ...                                  ...
# 113                                 0+0i                                 0+0i
# 114                                 0+0i                                 0+0i
# 115                                 0+0i                                 0+0i
# 116                                 0+0i                                 0+0i
# 117                                 0+0i                                 0+0i
#
#                                      2                                   3    \
# 0    -6.56765962213047+21.5867261998707i                                0+0i
# 1                                   0+0i                                0+0i
# 2     10.2679651856868-36.1328218177916i                                0+0i
# 3                                   0+0i    30.398343223854-132.80733432795i
# 4    -1.96818080476545+8.82006335745512i  -26.355985504208+119.500434274761i
# ..                                   ...                                 ...
# 113                                 0+0i                                0+0i
# 114                                 0+0i                                0+0i
# 115                                 0+0i                                0+0i
# 116                                 0+0i                                0+0i
# 117                                 0+0i                                0+0i
#
#                                      4                                    5    \
# 0                                   0+0i                                 0+0i
# 1                                   0+0i                                 0+0i
# 2    -1.96818080476545+8.82006335745512i                                 0+0i
# 3     -26.355985504208+119.500434274761i                                 0+0i
# 4     36.2253142014528-196.903930532742i  -3.89192866323697+17.6608527575459i
# ..                                   ...                                  ...
# 113                                 0+0i                                 0+0i
# 114                                 0+0i                                 0+0i
# 115                                 0+0i                                 0+0i
# 116                                 0+0i                                 0+0i
# 117                                 0+0i                                 0+0i
#
#       6                    7     8     9    ...   108   109   110   111   112  \
# 0    0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# 1    0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# 2    0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# 3    0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# 4    0+0i  0+37.4531835205992i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# ..    ...                  ...   ...   ...  ...   ...   ...   ...   ...   ...
# 113  0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# 114  0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# 115  0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# 116  0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
# 117  0+0i                 0+0i  0+0i  0+0i  ...  0+0i  0+0i  0+0i  0+0i  0+0i
#
#                                      113                                  114  \
# 0                                   0+0i                                 0+0i
# 1                                   0+0i                                 0+0i
# 2                                   0+0i                                 0+0i
# 3                                   0+0i                                 0+0i
# 4                                   0+0i                                 0+0i
# ..                                   ...                                  ...
# 113   23.7103829313552-107.252017136614i  -20.2732481269282+91.6703393565447i
# 114  -20.2732481269282+91.6703393565447i    23.1205840448554-104.53543640035i
# 115                                 0+0i                                 0+0i
# 116                                 0+0i                                 0+0i
# 117                                 0+0i                                 0+0i
#
#                                     115                                 116  \
# 0                                  0+0i                                0+0i
# 1                                  0+0i                                0+0i
# 2                                  0+0i                                0+0i
# 3                                  0+0i                                0+0i
# 4                                  0+0i                                0+0i
# ..                                  ...                                 ...
# 113                                0+0i                                0+0i
# 114                                0+0i                                0+0i
# 115  20.5834811509798-245.185584298436i                                0+0i
# 116                                0+0i  1.59072371159841-6.76903707063152i
# 117                                0+0i                                0+0i
#
#                                     117
# 0                                  0+0i
# 1                                  0+0i
# 2                                  0+0i
# 3                                  0+0i
# 4                                  0+0i
# ..                                  ...
# 113                                0+0i
# 114                                0+0i
# 115                                0+0i
# 116                                0+0i
# 117  10.8252097470663-35.9089792060997i
#
# [118 rows x 118 columns]

# %%
Y.max().max()
# Out:
# '9.98449716519147-34.062193811489i'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-ab8b43264c87> in <module>
# ----> 1 np.array(Y)-np.array(Y2)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
I = Y.to_numpy() * V.to_numpy();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-1bb595b39108> in <module>
# ----> 1 I = Y.to_numpy() * V.to_numpy();
#
# ValueError: operands could not be broadcast together with shapes (118,118) (800,118)

# %%
V1 = V.iloc[1,:]

# %%
V1.shape
# Out:
# (118,)

# %%
I = Y.to_numpy() * V1.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-ca3ba0ae60d9> in <module>
# ----> 1 I = complex(Y.to_numpy()) * V1.to_numpy()
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
'''
Goal: Perform OLS
Input - P, Q, V, Va, num_train, num_bus
Output - Xp, Xq, P_mape, Q_mape, Xv, Xva, V_mae, Va_mae

'''
import numpy as np
import pandas as pd

def OLS(P, Q, V, Va, I,Ia, num_train, num_bus):
    import pandas as pd
    import numpy as np
    import sklearn
    
    # Y = P.join(Q, lsuffix='_P', rsuffix='_Q')
    # X = Va.join(V, lsuffix='_Va', rsuffix='_V')
    X = pd.concat([P,Q,I,Ia],axis=1)
    

    from sklearn.linear_model import LinearRegression
    from sklearn.model_selection import cross_val_score

    '''ols = LinearRegression()
    scores = cross_val_score(ols, X, P, cv=5, scoring="neg_mean_absolute_percentage_error")
    P_mape = scores.mean()

    ols = LinearRegression()
    scores = cross_val_score(ols, X, Q, cv=5, scoring="neg_mean_absolute_percentage_error")
    Q_mape = scores.mean()

    ols2 = LinearRegression()
    scores = cross_val_score(ols2, Y, V, cv=5, scoring="neg_mean_absolute_error")
    V_mae = scores.mean()

    ols2 = LinearRegression()
    scores = cross_val_score(ols2, Y, Va, cv=5, scoring="neg_mean_absolute_error")
    Va_mae = scores.mean()

    # Find Xp, Xq, Xv, Xva - Try out on your own
    ols3 = LinearRegression()
    ols3.fit(X,P)
    arr1 = np.array(ols3.coef_)
    arr2 = np.array(ols3.intercept_)
    Xp = np.column_stack((arr1,arr2))

    ols4 = LinearRegression()
    ols4.fit(X,Q)
    arr1 = np.array(ols4.coef_)
    arr2 = np.array(ols4.intercept_)
    Xq = np.column_stack((arr1,arr2))
'''

    # X = [P Q I Ia]
    ols5 = LinearRegression()
    ols5.fit(X,V)
    arr1 = np.array(ols5.coef_)
    arr2 = np.array(ols5.intercept_)
    Xv = np.column_stack((arr1,arr2))

    ols6 = LinearRegression()
    ols6.fit(X,Va)
    arr1 = np.array(ols6.coef_)
    arr2 = np.array(ols6.intercept_)
    Xva = np.column_stack((arr1,arr2))

    #return [Xp, Xq, Xv, Xva, P_mape, Q_mape, V_mae, Va_mae]
    return [ Xv, Xva]

P = pd.read_csv('gen_data/P.csv', header = None)
Q = pd.read_csv('gen_data/Q.csv', header = None)
V = pd.read_csv('gen_data/V.csv', header = None)
Va = pd.read_csv('gen_data/Va.csv', header = None)
I= pd.read_csv('gen_data/I.csv', header = None)
Ia = pd.read_csv('gen_data/Ia.csv', header = None)
num_train = P.shape[0]
num_bus = P.shape[1]
 
#Scaling 
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

P=scaler.fit_transform(P)
P= pd.DataFrame(P)
Q=scaler.fit_transform(Q)
Q= pd.DataFrame(Q)
V=scaler.fit_transform(V)
V= pd.DataFrame(V)
Va=scaler.fit_transform(Va)
Va= pd.DataFrame(Va)
I=scaler.fit_transform(I)
I= pd.DataFrame(I)
Ia=scaler.fit_transform(Ia)
Ia= pd.DataFrame(Ia)
#Saving Scaled Data
P.to_csv('gen_data/Scaled/P.csv', header = None,index=False)
Q.to_csv('gen_data/Scaled/Q.csv', header = None,index=False)
V.to_csv('gen_data/Scaled/V.csv', header = None,index =False)
Va.to_csv('gen_data/Scaled/Va.csv', header = None,index=False)
I.to_csv('gen_data/Scaled/I.csv', header = None,index=False)
Ia.to_csv('gen_data/Scaled/Ia.csv', header = None,index=False)


# [Xp, Xq, Xv, Xva, P_mape, Q_mape, V_mae, Va_mae] = OLS(P, Q, V, Va, num_train, num_bus)
[ Xv, Xva] = OLS(P, Q, V, Va,I,Ia, num_train, num_bus)

np.savetxt("gen_data/Xv.csv", Xv, delimiter=",")
np.savetxt("gen_data/Xva.csv", Xva, delimiter=",")

print(Xv.shape)
print(Xva.shape)
# Out:
# (118, 473)
# (118, 473)
